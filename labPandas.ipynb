# %% [markdown]
# <a href="https://colab.research.google.com/github/geracedillo/AD2003B/blob/main/labPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Agustín Gómez Pérez - A01732897
# Gerardo Cedillo Corona - A01704232

# %% [markdown]
# #PRACTICA
# ### AD2004B.403.M2.EF2023
# ### Laboratorio de PANDAS
#
#
#
# > En este Lab practicaras el uso de **Pandas** para realizar análisis de datos. Partiremos de la carga de datos desde un archivo de Excel para despues manipular visualizar esto datos con Python.
# EL archivo de Excel debe de estar en Github.
#
#
#
# ##### Nombre del archivo: "labPandas"
# #### Utilizaremos el archivo "Superstore.xls"

# %% [markdown]
# ## PANDAS
# https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html
#
#
# **Importar** un archivo de datos con **pandas**
# >Como primer paso se debe importar la libreria de Pandas, lo cual nos da acceso a las funciones necesarias para manipulación de los datos.

# %%
# Importamos la Libreria pandas con el alias "pd"
import pandas as pd

# %% [markdown]
# ## Importar archivo de Excel
# > Es importante que tengan correcta la ruta donde esta el archivo, en este caso el archivo debe estar en el repositorio correspondiente a la clase de GitHub.

# %%
#Importar archivo en un dataframe
df= pd.read_excel('Superstore.xls')

# %% [markdown]
# # Conoce los Datos.
# Identificar y documentar de manera general que contiene el archivo de datos.
# Una buena idea es crear un glosario de términos donde se describa cada uno de los datos manejados.

# %%
#Ejecuta las intrucciones necesarias para conocer los datos. 
# METADATOS:Tipos de datos, tamaño del dataframe, nombres de columnas, etc.
# DATOS: Observa los datos de manera inicial, oberva los primeros n y los ultimos n, donde pruebes con varios valores de n
# Cada instrucción colocala en un renglón para que agregues la documentación necesaria de los que estas observando.

# %% [markdown]
# METADATOS

# %%
df.dtypes
#Los datos mayormente son "object" seran un a mezcla de "strings" y "floats", los "float64" son datos que permiten tener mas precisión decimal a costo de pesar mas"
# Out:
# Order ID          object
# Customer ID       object
# Customer Name     object
# Segment           object
# City              object
# Postal Code      float64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.shape
#Hay 9994 inputs y 15 variables
# Out:
# (9994, 15)

# %%
df.columns
#La base de datos parece ser de una tienda al tener variables sobre las compras de los clientes
# Out:
# Index(['Order ID', 'Customer ID', 'Customer Name', 'Segment', 'City',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.info()
#No hay datos nulos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Customer ID    9994 non-null   object
#  2   Customer Name  9994 non-null   object
#  3   Segment        9994 non-null   object
#  4   City           9994 non-null   object
#  5   Postal Code    9983 non-null   float64
#  6   Region         9994 non-null   object
#  7   Product ID     9994 non-null   object
#  8   Category       9994 non-null   object
#  9   Sub-Category   9994 non-null   object
#  10  Product Name   9994 non-null   object
#  11  Sales          9994 non-null   float64
#  12  Quantity       9994 non-null   int64
#  13  Discount       9994 non-null   float64
#  14  Profit         9994 non-null   float64
# dtypes: float64(4), int64(1), object(10)
# memory usage: 1.1+ MB

# %% [markdown]
# DATOS

# %%
df.head(5)
# Out:
#          Order ID Customer ID     Customer Name      Segment           City  \
# 0  CA-2018-140326    HW-14935   Helen Wasserman    Corporate        Chicago
# 1  CA-2016-130785    AG-10900     Arthur Gainer     Consumer      San Diego
# 2  CA-2015-105249    DH-13675     Duane Huffman  Home Office  San Francisco
# 3  CA-2018-125472    BD-11725  Bruce Degenhardt     Consumer      Lafayette
# 4  CA-2016-118423    DP-13390     Dennis Pardue  Home Office         Peoria
#
#    Postal Code   Region       Product ID   Category Sub-Category  \
# 0      60653.0  Central  FUR-BO-10000112  Furniture    Bookcases
# 1      92105.0     West  FUR-BO-10000330  Furniture    Bookcases
# 2      94122.0     West  FUR-BO-10000330  Furniture    Bookcases
# 3      70506.0    South  FUR-BO-10000330  Furniture    Bookcases
# 4      61604.0  Central  FUR-BO-10000362  Furniture    Bookcases
#
#                                         Product Name    Sales  Quantity  \
# 0   Bush Birmingham Collection Bookcase, Dark Cherry  825.174         9
# 1  Sauder Camden County Barrister Bookcase, Plank...  411.332         4
# 2  Sauder Camden County Barrister Bookcase, Plank...  411.332         4
# 3  Sauder Camden County Barrister Bookcase, Plank...  241.960         2
# 4                 Sauder Inglewood Library Bookcases  359.058         3
#
#    Discount    Profit
# 0      0.30 -117.8820
# 1      0.15   -4.8392
# 2      0.15   -4.8392
# 3      0.00   33.8744
# 4      0.30  -35.9058

# %%
df.tail(15)
# Out:
#             Order ID Customer ID       Customer Name      Segment  \
# 9979  CA-2015-100867    EH-14125   Eugene Hildebrand  Home Office
# 9980  CA-2017-151141    DW-13480       Dianna Wilson  Home Office
# 9981  CA-2016-155068    RA-19285        Ralph Arnett     Consumer
# 9982  CA-2017-139381    RF-19840     Roy Französisch     Consumer
# 9983  CA-2016-121608    JB-15400    Jennifer Braxton    Corporate
# 9984  CA-2015-165309    KD-16270       Karen Daniels     Consumer
# 9985  CA-2017-117590    GH-14485           Gene Hale    Corporate
# 9986  CA-2018-145233    DV-13465    Dianna Vittorini     Consumer
# 9987  CA-2015-136399    CC-12100     Chad Cunningham  Home Office
# 9988  CA-2018-122196    CA-12265  Christina Anderson     Consumer
# 9989  CA-2018-144498    MB-18085          Mick Brown     Consumer
# 9990  CA-2015-167199    ME-17320       Maria Etezadi  Home Office
# 9991  CA-2018-121048    TC-21295       Toby Carlisle     Consumer
# 9992  CA-2018-167395    KM-16720        Kunst Miller     Consumer
# 9993  CA-2016-128608    CS-12490    Cindy Schnelling    Corporate
#
#              City  Postal Code   Region       Product ID    Category  \
# 9979     Lakewood      90712.0     West  TEC-PH-10004922  Technology
# 9980      Detroit      48205.0  Central  TEC-PH-10004924  Technology
# 9981     Lakeland      33801.0    South  TEC-PH-10004924  Technology
# 9982   Chesapeake      23320.0    South  TEC-PH-10004924  Technology
# 9983      Bristol       6010.0     East  TEC-PH-10004959  Technology
# 9984      Houston      77095.0  Central  TEC-PH-10004959  Technology
# 9985   Richardson      75080.0  Central  TEC-PH-10004977  Technology
# 9986       Denver      80219.0     West  TEC-PH-10004977  Technology
# 9987  Los Angeles      90049.0     West  TEC-PH-10004977  Technology
# 9988   Wilmington      19805.0     East  TEC-PH-10004977  Technology
# 9989    Charlotte      28205.0    South  TEC-PH-10004977  Technology
# 9990    Henderson      42420.0    South  TEC-PH-10004977  Technology
# 9991  Westminster      92683.0     West  TEC-PH-10004977  Technology
# 9992       Lowell       1852.0     East  TEC-PH-10004977  Technology
# 9993       Toledo      43615.0     East  TEC-PH-10004977  Technology
#
#      Sub-Category                                       Product Name  \
# 9979       Phones             RCA Visys Integrated PBX 8-Line Router
# 9980       Phones  SKILCRAFT Telephone Shoulder Rest, 2" x 6.5" x...
# 9981       Phones  SKILCRAFT Telephone Shoulder Rest, 2" x 6.5" x...
# 9982       Phones  SKILCRAFT Telephone Shoulder Rest, 2" x 6.5" x...
# 9983       Phones             Classic Ivory Antique Telephone ZL1810
# 9984       Phones             Classic Ivory Antique Telephone ZL1810
# 9985       Phones                                        GE 30524EE4
# 9986       Phones                                        GE 30524EE4
# 9987       Phones                                        GE 30524EE4
# 9988       Phones                                        GE 30524EE4
# 9989       Phones                                        GE 30524EE4
# 9990       Phones                                        GE 30524EE4
# 9991       Phones                                        GE 30524EE4
# 9992       Phones                                        GE 30524EE4
# 9993       Phones                                        GE 30524EE4
#
#          Sales  Quantity  Discount    Profit
# 9979   321.552         6       0.2   20.0970
# 9980    14.780         2       0.0    3.9906
# 9981    11.824         2       0.2    1.0346
# 9982    29.560         4       0.0    7.9812
# 9983   100.490         1       0.0   25.1225
# 9984   241.176         3       0.2   15.0735
# 9985  1097.544         7       0.2  123.4737
# 9986   470.376         3       0.2   52.9173
# 9987   627.168         4       0.2   70.5564
# 9988   391.980         2       0.0  113.6742
# 9989   627.168         4       0.2   70.5564
# 9990   391.980         2       0.0  113.6742
# 9991   470.376         3       0.2   52.9173
# 9992   979.950         5       0.0  284.1855
# 9993   235.188         2       0.4  -43.1178

# %%
df.count()
#Postal code posee datos faltantes o NA
# Out:
# Order ID         9994
# Customer ID      9994
# Customer Name    9994
# Segment          9994
# City             9994
# Postal Code      9983
# Region           9994
# Product ID       9994
# Category         9994
# Sub-Category     9994
# Product Name     9994
# Sales            9994
# Quantity         9994
# Discount         9994
# Profit           9994
# dtype: int64

# %%
df.nunique()
#Existen valores repetidos pero en el contexto actual es aceptable
# Out:
# Order ID         5009
# Customer ID       793
# Customer Name     793
# Segment             3
# City              531
# Postal Code       630
# Region              4
# Product ID       1862
# Category            3
# Sub-Category       17
# Product Name     1850
# Sales            6144
# Quantity           14
# Discount           12
# Profit           7545
# dtype: int64

# %%
df.describe()
#Hay una media de ventas de $623.24 u, media de unidades de 3.78 u, y una media de ganancia de $28.65
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9983.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55245.233297    229.858001     3.789574     0.156203    28.656896
# std    32038.715955    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    57103.000000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# # **FILTROS**

# %% [markdown]
# ### Mostrar columas especificas de un dataframe.
# Crea un dataframe "dfCLientes" donde almacenes el ID del CLiente y su nombre.
# Muestra el dataframe.
#
# dataframe[["col1", "col2"]]

# %%
dfCLientes =  df[['Customer ID', 'Customer Name']]
dfCLientes
#El data frame tiene registrados 9994 compras
# Out:
#      Customer ID     Customer Name
# 0       HW-14935   Helen Wasserman
# 1       AG-10900     Arthur Gainer
# 2       DH-13675     Duane Huffman
# 3       BD-11725  Bruce Degenhardt
# 4       DP-13390     Dennis Pardue
# ...          ...               ...
# 9989    MB-18085        Mick Brown
# 9990    ME-17320     Maria Etezadi
# 9991    TC-21295     Toby Carlisle
# 9992    KM-16720      Kunst Miller
# 9993    CS-12490  Cindy Schnelling
#
# [9994 rows x 2 columns]

# %% [markdown]
# **CLIENTES**.
# ¿Cuantos clientes se tienen?
# Crea un dataframe con los IDs y nombre de clientes sin que estos se repitan.
# Muestra la información.

# %%
dfCLfilt = dfCLientes.drop_duplicates('Customer Name')
dfCLfilt
#Hay 793 clientes
# Out:
#      Customer ID     Customer Name
# 0       HW-14935   Helen Wasserman
# 1       AG-10900     Arthur Gainer
# 2       DH-13675     Duane Huffman
# 3       BD-11725  Bruce Degenhardt
# 4       DP-13390     Dennis Pardue
# ...          ...               ...
# 4558    MW-18235  Mitch Willingham
# 5061    PB-19210    Phillip Breyer
# 6029    BD-11560    Brendan Dodson
# 6744    CH-12070       Cathy Hwang
# 9921    JR-15700    Jocasta Rupert
#
# [793 rows x 2 columns]

# %% [markdown]
# **Analiza los datos unicos.**
#
# Obten la lista de ciudades,segmentos, regiones y categorias. De cada uno conoce la cantidad y visualiza las listas.
# Crea un dataframe nuevo por cada consulta, el unique genera un arreglo numpy, conviertelo a dataframe, vizualizalo.

# %%
import numpy as np

# %% [markdown]
# # **Filtros con**  iloc - loc
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html?highlight=iloc#pandas.DataFrame.iloc
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html

# %% [markdown]
# Con la instrucción iloc y el dataframe dfDatos
#
# *   Muestra los primeros 10 registros.
# *   Muestra los registros del 20 al 25.
# *   Muestra 10 registros con indices seleccionados aleatoreamente
# *   Muestra los registros del 100 al 120, pero solo las columnas 4, 5 y 6

# %%
# iloc

df.iloc[:10]
# Out:
#          Order ID Customer ID        Customer Name      Segment  \
# 0  CA-2018-140326    HW-14935      Helen Wasserman    Corporate
# 1  CA-2016-130785    AG-10900        Arthur Gainer     Consumer
# 2  CA-2015-105249    DH-13675        Duane Huffman  Home Office
# 3  CA-2018-125472    BD-11725     Bruce Degenhardt     Consumer
# 4  CA-2016-118423    DP-13390        Dennis Pardue  Home Office
# 5  CA-2015-156349    ML-17395  Marina Lichtenstein    Corporate
# 6  CA-2017-165848    EN-13780        Edward Nazzal     Consumer
# 7  US-2015-123183    GR-14560    Georgia Rosenberg    Corporate
# 8  CA-2015-133592    KM-16375     Katherine Murray  Home Office
# 9  CA-2018-161200    SV-20365          Seth Vernon     Consumer
#
#             City  Postal Code   Region       Product ID   Category  \
# 0        Chicago      60653.0  Central  FUR-BO-10000112  Furniture
# 1      San Diego      92105.0     West  FUR-BO-10000330  Furniture
# 2  San Francisco      94122.0     West  FUR-BO-10000330  Furniture
# 3      Lafayette      70506.0    South  FUR-BO-10000330  Furniture
# 4         Peoria      61604.0  Central  FUR-BO-10000362  Furniture
# 5    Los Angeles      90008.0     West  FUR-BO-10000362  Furniture
# 6  New York City      10035.0     East  FUR-BO-10000362  Furniture
# 7     Wilmington      19805.0     East  FUR-BO-10000362  Furniture
# 8     Providence       2908.0     East  FUR-BO-10000362  Furniture
# 9      Lafayette      70506.0    South  FUR-BO-10000468  Furniture
#
#   Sub-Category                                       Product Name     Sales  \
# 0    Bookcases   Bush Birmingham Collection Bookcase, Dark Cherry   825.174
# 1    Bookcases  Sauder Camden County Barrister Bookcase, Plank...   411.332
# 2    Bookcases  Sauder Camden County Barrister Bookcase, Plank...   411.332
# 3    Bookcases  Sauder Camden County Barrister Bookcase, Plank...   241.960
# 4    Bookcases                 Sauder Inglewood Library Bookcases   359.058
# 5    Bookcases                 Sauder Inglewood Library Bookcases   290.666
# 6    Bookcases                 Sauder Inglewood Library Bookcases   136.784
# 7    Bookcases                 Sauder Inglewood Library Bookcases  1025.880
# 8    Bookcases                 Sauder Inglewood Library Bookcases   341.960
# 9    Bookcases            O'Sullivan 2-Shelf Heavy-Duty Bookcases   145.740
#
#    Quantity  Discount    Profit
# 0         9      0.30 -117.8820
# 1         4      0.15   -4.8392
# 2         4      0.15   -4.8392
# 3         2      0.00   33.8744
# 4         3      0.30  -35.9058
# 5         2      0.15   27.3568
# 6         1      0.20    5.1294
# 7         6      0.00  235.9524
# 8         2      0.00   78.6508
# 9         3      0.00   23.3184

# %%
df.iloc[20:26]
# Out:
#           Order ID Customer ID   Customer Name      Segment           City  \
# 20  US-2016-164238    JW-15955  Joni Wasserman     Consumer   Philadelphia
# 21  CA-2018-137449    ME-17725       Max Engle     Consumer         Dallas
# 22  CA-2018-140963    MT-18070   Michelle Tran  Home Office    Los Angeles
# 23  CA-2018-108070    JE-15745      Joel Eaton     Consumer       San Jose
# 24  CA-2015-154599    KN-16450     Kean Nguyen    Corporate  Redondo Beach
# 25  CA-2017-156251    TS-21160   Theresa Swint    Corporate     West Allis
#
#     Postal Code   Region       Product ID   Category Sub-Category  \
# 20      19120.0     East  FUR-BO-10000780  Furniture    Bookcases
# 21      75220.0  Central  FUR-BO-10000780  Furniture    Bookcases
# 22      90045.0     West  FUR-BO-10001337  Furniture    Bookcases
# 23      95123.0     West  FUR-BO-10001337  Furniture    Bookcases
# 24      90278.0     West  FUR-BO-10001337  Furniture    Bookcases
# 25      53214.0  Central  FUR-BO-10001337  Furniture    Bookcases
#
#                                          Product Name     Sales  Quantity  \
# 20  O'Sullivan Plantations 2-Door Library in Landv...  301.4700         3
# 21  O'Sullivan Plantations 2-Door Library in Landv...  409.9992         3
# 22     O'Sullivan Living Dimensions 2-Shelf Bookcases  514.1650         5
# 23     O'Sullivan Living Dimensions 2-Shelf Bookcases  102.8330         1
# 24     O'Sullivan Living Dimensions 2-Shelf Bookcases  308.4990         3
# 25     O'Sullivan Living Dimensions 2-Shelf Bookcases  241.9600         2
#
#     Discount    Profit
# 20      0.50 -204.9996
# 21      0.32  -96.4704
# 22      0.15  -30.2450
# 23      0.15   -6.0490
# 24      0.15  -18.1470
# 25      0.00   24.1960

# %%
df.iloc[50:60]
# Out:
#           Order ID Customer ID    Customer Name    Segment           City  \
# 50  CA-2018-159793    SV-20365      Seth Vernon   Consumer   Philadelphia
# 51  CA-2018-110198    AG-10900    Arthur Gainer   Consumer  Coral Springs
# 52  CA-2017-102981    MO-17500    Mary O'Rourke   Consumer  New York City
# 53  US-2018-132059    AP-10915   Arthur Prichep   Consumer   Fort Collins
# 54  CA-2017-147137    AA-10645    Anna Andreadi   Consumer  San Francisco
# 55  CA-2018-115105    BD-11770      Bryan Davis   Consumer  New York City
# 56  CA-2016-133585    CM-12715   Craig Molinari  Corporate        Houston
# 57  CA-2018-142461    KT-16480    Kean Thornton   Consumer         Dallas
# 58  CA-2016-130183    PO-18850  Patrick O'Brill   Consumer        Houston
# 59  CA-2018-144491    CJ-12010  Caroline Jumper   Consumer        Houston
#
#     Postal Code   Region       Product ID   Category Sub-Category  \
# 50      19140.0     East  FUR-BO-10001798  Furniture    Bookcases
# 51      33065.0    South  FUR-BO-10001798  Furniture    Bookcases
# 52      10035.0     East  FUR-BO-10001811  Furniture    Bookcases
# 53      80525.0     West  FUR-BO-10001811  Furniture    Bookcases
# 54      94109.0     West  FUR-BO-10001811  Furniture    Bookcases
# 55      10024.0     East  FUR-BO-10001811  Furniture    Bookcases
# 56      77070.0  Central  FUR-BO-10001811  Furniture    Bookcases
# 57      75217.0  Central  FUR-BO-10001811  Furniture    Bookcases
# 58      77041.0  Central  FUR-BO-10001811  Furniture    Bookcases
# 59      77070.0  Central  FUR-BO-10001811  Furniture    Bookcases
#
#                                          Product Name      Sales  Quantity  \
# 50                  Bush Somerset Collection Bookcase   130.9800         2
# 51                  Bush Somerset Collection Bookcase   314.3520         3
# 52  Atlantic Metals Mobile 5-Shelf Bookcases, Cust...   722.3520         3
# 53  Atlantic Metals Mobile 5-Shelf Bookcases, Cust...   180.5880         2
# 54  Atlantic Metals Mobile 5-Shelf Bookcases, Cust...  1279.1650         5
# 55  Atlantic Metals Mobile 5-Shelf Bookcases, Cust...   240.7840         1
# 56  Atlantic Metals Mobile 5-Shelf Bookcases, Cust...  1227.9984         6
# 57  Atlantic Metals Mobile 5-Shelf Bookcases, Cust...   204.6664         1
# 58  Atlantic Metals Mobile 5-Shelf Bookcases, Cust...   613.9992         3
# 59  Atlantic Metals Mobile 5-Shelf Bookcases, Cust...  1023.3320         5
#
#     Discount    Profit
# 50      0.50  -89.0664
# 51      0.20  -15.7176
# 52      0.20   90.2940
# 53      0.70 -240.7840
# 54      0.15  225.7350
# 55      0.20   30.0980
# 56      0.32  -36.1176
# 57      0.32   -6.0196
# 58      0.32  -18.0588
# 59      0.32  -30.0980

# %%
df.iloc[100:121,4:7]
# Out:
#                  City  Postal Code   Region
# 100  Colorado Springs      80906.0     West
# 101         Watertown      13601.0     East
# 102      Apple Valley      92307.0     West
# 103     New York City      10024.0     East
# 104     San Francisco      94110.0     West
# 105          Amarillo      79109.0  Central
# 106           Holyoke       1040.0     East
# 107    Pembroke Pines      33024.0    South
# 108          Franklin       2038.0     East
# 109      Philadelphia      19120.0     East
# 110      Murfreesboro      37130.0    South
# 111           Seattle      98105.0     West
# 112         San Diego      92037.0     West
# 113           Kenosha      53142.0  Central
# 114           Seattle      98103.0     West
# 115           Everett       2149.0     East
# 116           Chicago      60623.0  Central
# 117     New York City      10024.0     East
# 118     San Francisco      94110.0     West
# 119     San Francisco      94109.0     West
# 120     New York City      10011.0     East

# %% [markdown]
# Con la instrucción loc:
#
#
# *   En una nuev df Asigna el ID de la orden como dato indice.
# *   Realiza la busqueda de la orden "CA-2015-154599"
# *   Obtnen los registros con Sales mayor a 5000. ¿cuantos son?

# %%
# loc

# %%
df.loc[df['Customer ID'] == "CA-2015-154599"3]
# Out:
#   File "<ipython-input-29-87eba924477d>", line 1
#     df.loc[df['Customer ID'] == "CA-2015-154599"3]
#                                                 ^
# SyntaxError: invalid syntax

# %%
dfsal = df.loc[df['Sales'] > 5000]
dfsal['Sales'].count()
#Hay 19 ventas arriba de $5000
# Out:
# 19

# %% [markdown]
# ## Estadisticas básicas con pandas
# https://datatofish.com/use-pandas-to-calculate-stats-from-an-imported-csv-file/
#
# df.describe()
# Mean, sum, Maximum, Minimum, Count, Median, Standard deviation, Variance.
#
# Obrten las estadisticas de los datos.
#
#
# _________

# %%
# Estadisticas basicas
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9983.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55245.233297    229.858001     3.789574     0.156203    28.656896
# std    32038.715955    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    57103.000000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
print(max(df))
print(min(df))
# Out:
# Sub-Category
# Category

# %% [markdown]
# **### Estadisticas con una condición**

# %% [markdown]
# Obten el promedio de utilidad de la región Central
#
# Ejemplo de salida:
#
# ***Promedio de utilidad de ordenes de la región central : 23.45***

# %%
# utiliza la intrucción loc para filtrar
print(df['Region']. value_counts())
sum(df.loc[df['Region']=='Central',:])
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-4e25ebf56307> in <module>
#       1 # utiliza la intrucción loc para filtrar
#       2 print(df['Region']. value_counts())
# ----> 3 sum(df.loc[df['Region']=='Central',:])
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# Obten la suma de ventas de la categoría "Technology"

# %% [markdown]
# # **Group By**
# >La instrucción **groupby** realiza agrupamientos por uno o más datos, de tal forma que podremos realizar cálculos de datos por esos mismos grupos.

# %% [markdown]
# **TOP TEN x Ventas**
#
# Obten las ventas (cantidad , ventas , descuento) por ciudad ordenado de manera descendente en cuanto a las ventas.

# %%
#Primer paso usar groupby y generar un df
#Ordenar el daraframe de manera descendente y mostrar los primeros 10
dfventas = df[['Sales','Quantity','Discount']]
ventas= dfventas.groupby(['Sales'])

# %% [markdown]
# **Generar otras dos vistas que sean de utilidad (con el groupby)**
# Analizar otras dos vistas que consideran puden ser utiles para conocer más sobre los datos.

# %% [markdown]
# # **EXPORTACIÓN**
#
# Exportar los df a archivos de EXCEL.

# %%
# Exportar un df a un archivo de EXCEL.

# %% [markdown]
# ---
#
#
# # **SEGUNDA PARTE**

# %% [markdown]
# ## ¿y las Gráficas?
#
# Veamos la libreria **matplotlib**

# %%
import matplotlib.pyplot as plt  # solo importamos del módulo  pyplot

# %% [markdown]
# ### NORMALIZAR
# Para poder comparar las ventas con los descuentos y ver si tienen una correlación debemos de ponerlos en una misma escala, para esto utilizremos la libreria **sklearn**

# %%
from sklearn import preprocessing
import seaborn as sns
